# %%
import os
os.chdir("../")

# %%
import numpy as np
import torch
import json
from torch import nn

from cids.util import misc_funcs as misc
from cids.data import SCVICCIDSDataset

import matplotlib.pyplot as plt
from cids.data import get_SCVIC_dataloader
from cids.util.config import read, transform_ray_hp_config
from cids.training.supervised import train_mlp_ray
from cids.util import misc_funcs as misc
from cids.util.metrics import top1_accuracy, combined_loss
from cids.models.transformer import TransformerEncoder
from cids.models.nn import MLP

# %%
tdl, vdl = get_SCVIC_dataloader(8, 2, host_embeddings=True)
# Out:
# INFO:cids.data:load train_dataloader based on /opt/gildemeister/gildemeister-implementation/data/scvic/train_indices.txt
# DEBUG:cids.data:Start loading embeddings
# INFO:cids.data:Loading SCVIC-CIDS dataset
# DEBUG:cids.data:Loading normal
# DEBUG:cids.data:Loading malicious
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 tdl, vdl = get_SCVIC_dataloader(8, 2, host_embeddings=True)
#
# File /opt/gildemeister/gildemeister-implementation/cids/data.py:433, in get_SCVIC_dataloader(batch_size, num_workers, exclude, validation, test, random_state, network_data, host_data, host_embeddings)
#     431 logger.info(f"load train_dataloader based on {os.path.join(misc.data(), "scvic/train_indices.txt")}")
#     432 idxs = np.loadtxt(os.path.join(misc.data(), "scvic/train_indices.txt"), dtype=int)
# --> 433 dataset = SCVICCIDSDataset(misc.data_raw(scvic=True), exclude_classes=exclude, subset=idxs, network_data=network_data, host_data=host_data, host_embeddings=host_embeddings)
#     435 if not validation:
#     436     return torch.utils.data.DataLoader(dataset, batch_size=batch_size, num_workers=num_workers, shuffle=True)
#
# File /opt/gildemeister/gildemeister-implementation/cids/data.py:236, in SCVICCIDSDataset.__init__(self, path, data, min_samples_per_class, exclude_classes, subset, network_data, host_data, host_embeddings)
#     234 logger.debug("Loading malicious")
#     235 with open(os.path.join(misc.data_raw("scvic-cids"), "CidsSampleAttack_Tensor_28.pkl"), 'rb') as f:
# --> 236     malicious_data = pkl.load(f)
#     238 logger.debug("Load occurences")
#     239 occurences = {}
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/storage.py:520, in _load_from_bytes(b)
#     519 def _load_from_bytes(b):
# --> 520     return torch.load(io.BytesIO(b), weights_only=False)
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/serialization.py:1392, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1390     except pickle.UnpicklingError as e:
#    1391         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1392 return _legacy_load(
#    1393     opened_file, map_location, pickle_module, **pickle_load_args
#    1394 )
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/serialization.py:1646, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1644 unpickler = UnpicklerWrapper(f, **pickle_load_args)
#    1645 unpickler.persistent_load = persistent_load
# -> 1646 result = unpickler.load()
#    1648 deserialized_storage_keys = pickle_module.load(f, **pickle_load_args)
#    1650 if torch._guards.active_fake_mode() is None:
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/serialization.py:1577, in _legacy_load.<locals>.persistent_load(saved_id)
#    1574         obj = restore_location(obj, location)
#    1575     # TODO: Once we decide to break serialization FC, we can
#    1576     # stop wrapping with TypedStorage
# -> 1577     typed_storage = torch.storage.TypedStorage(
#    1578         wrap_storage=obj, dtype=dtype, _internal=True
#    1579     )
#    1580     deserialized_objects[root_key] = typed_storage
#    1581 else:
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/storage.py:674, in TypedStorage.__new__(cls, wrap_storage, dtype, device, _internal, *args)
#     671     self._setitem(slice(0, self._size()), value)
#     672     return self
# --> 674 def __new__(
#     675     cls,
#     676     *args,
#     677     wrap_storage=None,
#     678     dtype=None,
#     679     device=None,
#     680     _internal=False,
#     681 ):
#     682     if not _internal:
#     683         _warn_typed_storage_removal()
#
# KeyboardInterrupt:

# %%
data = next(iter(tdl))

# %%
label = data[-1]
if len(data) == 2:
    inp = torch.flatten(data[0], start_dim=1)
else:
    inps = [torch.flatten(data[i], start_dim=1) for i in range(len(data) - 1)]
    inp = torch.cat(inps, dim=1)

# %%
print(inp.shape)
for d in data[:-1]:
    print(d.shape)
    print(torch.flatten(d, start_dim=1).shape)
# Out:
# torch.Size([8, 356])
# torch.Size([8, 132])
# torch.Size([8, 132])
# torch.Size([8, 28, 8])
# torch.Size([8, 224])

# %%
def train_step_collaborative(src: tuple[torch.Tensor, ...], tgt: torch.Tensor, model: nn.Module, loss_criterion: callable, optimizer: torch.optim.Optimizer, accuracy: callable=None, alpha = 0.):
    
    optimizer.zero_grad()

    outputs = model(*src)

    loss = loss_criterion(*outputs, tgt, alpha=alpha)

    loss.backward()
    optimizer.step()

    if accuracy is not None:
        acc = accuracy(outputs[0], tgt)
        return loss, acc
    
    return loss

# %%
config = read(os.path.join(misc.root(), "config/00_hyperparameter_optimization/collaborative_classification/CIDS-1.yaml"), convert_tuple=True)

# %%
hp_config = config["hp_config"]
print(hp_config["lr"])
# Out:
# (1e-06, 0.001, 'loguniform')

# %%
config = transform_ray_hp_config(hp_config)
# hp_config["model"]["hidden_dims"] = [128, 64]
# hp_config["lr"] = 1e-4

# %%
network_config = config["model"]["network"]
host_config = config["model"]["host"]
host_config["n_head"] = host_config["n_head"].sample()
host_config["factor_dim_feedforward"] = host_config["factor_dim_feedforward"].sample()
embedding_config = config["model"]["embedding"]
embedding_config["n_head"] = embedding_config["n_head"].sample()
embedding_config["head"] = embedding_config["head"].sample()
embedding_config["d_model"] = embedding_config["d_model"].sample()
embedding_config["factor_dim_feedforward"] = embedding_config["factor_dim_feedforward"].sample()
aggregation_config = config["model"]["aggregation"]
aggregation_config["hidden_dims"] = aggregation_config["hidden_dims"].sample()

config["model"]["network"] = network_config
config["model"]["host"] = host_config
config["model"]["embedding"] = embedding_config

config["alpha"] = config["alpha"].sample()
config["lr"] = config["lr"].sample()
config["epochs"] = 1

# %%
import logging 
logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger()

# %%
class CollaborativeIDSNet(nn.Module):

    def __init__(self, network_encoder: nn.Module, host_encoder: nn.Module, embedding_encoder: nn.Module, aggregation_module: nn.Module):
        super().__init__()

        self.network_encoder = network_encoder
        self.host_encoder = nn.Sequential(host_encoder, nn.Flatten())
        self.embedding_encoder = nn.Sequential(embedding_encoder, nn.Flatten())
        self.aggregation_module = nn.Sequential(nn.ReLU(), aggregation_module)

    def forward(self, x_network: torch.Tensor, x_host: torch.Tensor, x_embeddings: torch.Tensor):

        x_network = self.network_encoder(x_network)
        x_host = self.host_encoder(x_host)
        x_embeddings = self.embedding_encoder(x_embeddings)


        x_agg = torch.cat([x_network, x_host, x_embeddings], dim=1)
        logits = self.aggregation_module(x_agg)

        return logits, x_network

# %%
device = "cuda:0"
logger.debug(f"Use device {device}")

logger.info("Load model")

network_config = config["model"]["network"]
host_config = config["model"]["host"]
host_config["dim_feedforward"] = int(host_config.pop("factor_dim_feedforward") * host_config["d_model"])
embedding_config = config["model"]["embedding"]
embedding_config["dim_feedforward"] = int(embedding_config.pop("factor_dim_feedforward") * embedding_config["d_model"])
aggregation_config = config["model"]["aggregation"]
aggregation_config["input_dim"] = int(network_config["output_dim"] \
    + host_config["d_model"] * host_config["max_len"] \
    + (embedding_config["head"] if embedding_config["head"] is not None else embedding_config["d_model"]) * embedding_config["max_len"])

model = CollaborativeIDSNet(
    network_encoder=MLP(**network_config),
    host_encoder=TransformerEncoder(**host_config),
    embedding_encoder=TransformerEncoder(**embedding_config),
    aggregation_module=MLP(**aggregation_config)
)

logger.info("load data")

model.to(device=device)
# Out:
# DEBUG:root:Use device cuda:0
# INFO:root:Load model
# INFO:root:load data
# CollaborativeIDSNet(
#   (network_encoder): MLP(
#     (input_layer): Linear(in_features=132, out_features=128, bias=True)
#     (hidden_layers): ModuleList(
#       (0): Linear(in_features=128, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#     (output_layer): Linear(in_features=64, out_features=15, bias=True)
#     (dropout): Identity()
#   )
#   (host_encoder): Sequential(
#     (0): TransformerEncoder(
#       (transformer_layers): ModuleList(
#         (0): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=8, out_features=8, bias=True)
#           )
#           (linear1): Linear(in_features=8, out_features=4, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=4, out_features=8, bias=True)
#           (norm1): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (embedding): Identity()
#       (pos_encoding): PositionalEncoding(
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (head): Identity()
#     )
#     (1): Flatten(start_dim=1, end_dim=-1)
#   )
#   (embedding_encoder): Sequential(
#     (0): TransformerEncoder(
#       (transformer_layers): ModuleList(
#         (0): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=128, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=128, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (embedding): Linear(in_features=768, out_features=256, bias=True)
#       (pos_encoding): PositionalEncoding(
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (head): Linear(in_features=256, out_features=8, bias=True)
#     )
#     (1): Flatten(start_dim=1, end_dim=-1)
#   )
#   (aggregation_module): Sequential(
#     (0): ReLU()
#     (1): MLP(
#       (input_layer): Linear(in_features=1039, out_features=256, bias=True)
#       (hidden_layers): ModuleList()
#       (output_layer): Linear(in_features=256, out_features=15, bias=True)
#       (dropout): Identity()
#     )
#   )
# )

# %%
cooloff = 0
best_loss = float('inf')

params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.AdamW(params=params, lr=config["lr"])
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=config["epochs"])

logger.info(f"Start training for {config['epochs']} epochs, under ray conditions")

total_steps = 0
alpha = config["alpha"]
loss_fnc = combined_loss
accuracy = top1_accuracy

for epoch in range(config["epochs"]):
    logger.info(f"Start epoch {epoch}")
    total_loss = 0
    total_acc = 0
    steps = 0

    for data in tdl:
        for d in data:
            print(d.dtype)
        label = data[-1]

        inp_network = data[0].to(device)
        inp_host = data[1].to(device)
        inp_embedding = data[2].to(device)
        label = label.to(device=device)

        loss, acc = train_step_collaborative(
            (inp_network, inp_host, inp_embedding),
            label,
            model=model,
            loss_criterion=loss_fnc,
            optimizer=optimizer,
            accuracy=accuracy,
            alpha=alpha
        )

        total_loss += loss.item()
        total_acc += acc.item()
        
        steps += 1
        total_steps += 1

    epoch_loss = total_loss / steps
    epoch_acc = total_acc / steps
    cooloff += 1
# Out:
# INFO:root:Start training for 1 epochs, under ray conditions
# INFO:root:Start epoch 0
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# ...
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# torch.float32
# torch.float32
# torch.float32
# torch.int64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 31
#      28 inp_embedding = data[2].to(device)
#      29 label = label.to(device=device)
# ---> 31 loss, acc = train_step_collaborative(
#      32     (inp_network, inp_host, inp_embedding),
#      33     label,
#      34     model=model,
#      35     loss_criterion=loss_fnc,
#      36     optimizer=optimizer,
#      37     accuracy=accuracy,
#      38     alpha=alpha
#      39 )
#      41 total_loss += loss.item()
#      42 total_acc += acc.item()
#
# Cell In[16], line 5, in train_step_collaborative(src, tgt, model, loss_criterion, optimizer, accuracy, alpha)
#       1 def train_step_collaborative(src: tuple[torch.Tensor, ...], tgt: torch.Tensor, model: nn.Module, loss_criterion: callable, optimizer: torch.optim.Optimizer, accuracy: callable=None, alpha = 0.):
#       3     optimizer.zero_grad()
# ----> 5     outputs = model(*src)
#       7     loss = loss_criterion(*outputs, tgt, alpha=alpha)
#       9     loss.backward()
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[30], line 14, in CollaborativeIDSNet.forward(self, x_network, x_host, x_embeddings)
#      11 def forward(self, x_network: torch.Tensor, x_host: torch.Tensor, x_embeddings: torch.Tensor):
#      13     x_network = self.network_encoder(x_network)
# ---> 14     x_host = self.host_encoder(x_host)
#      15     x_embeddings = self.embedding_encoder(x_embeddings)
#      18     x_agg = torch.cat([x_network, x_host, x_embeddings], dim=1)
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/gildemeister/gildemeister-implementation/cids/models/transformer.py:66, in TransformerEncoder.forward(self, src)
#      64 src = self.pos_encoding(src)
#      65 for layer in self.transformer_layers:
# ---> 66     src = layer(src)
#      67 src = self.head(src)
#      69 return src
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/transformer.py:898, in TransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask, is_causal)
#     895 x = src
#     896 if self.norm_first:
#     897     x = x + self._sa_block(
# --> 898         self.norm1(x), src_mask, src_key_padding_mask, is_causal=is_causal
#     899     )
#     900     x = x + self._ff_block(self.norm2(x))
#     901 else:
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/modules/normalization.py:217, in LayerNorm.forward(self, input)
#     216 def forward(self, input: Tensor) -> Tensor:
# --> 217     return F.layer_norm(
#     218         input, self.normalized_shape, self.weight, self.bias, self.eps
#     219     )
#
# File /opt/gildemeister/miniconda3/envs/cids3.12/lib/python3.12/site-packages/torch/nn/functional.py:2900, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2890 if has_torch_function_variadic(input, weight, bias):
#    2891     return handle_torch_function(
#    2892         layer_norm,
#    2893         (input, weight, bias),
#    (...)
#    2898         eps=eps,
#    2899     )
# -> 2900 return torch.layer_norm(
#    2901     input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled
#    2902 )
#
# KeyboardInterrupt:
